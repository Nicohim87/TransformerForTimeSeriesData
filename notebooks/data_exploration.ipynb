# %%
import pandas as pd

# %%
df = pd.read_csv("../data/global_air_quality_2014_2025.csv")
df = df.sort_values(["Country", "City", "Date"])
df.head()
# Out:
#         Country            State      City        Date  PM2.5 (ug/m3)  \
# 34    Australia  South Australia  Adelaide  2014-01-01          17.01
# 2339  Australia  South Australia  Adelaide  2014-02-01           7.16
# 4644  Australia  South Australia  Adelaide  2014-03-01           6.04
# 6949  Australia  South Australia  Adelaide  2014-04-01           6.48
# 9254  Australia  South Australia  Adelaide  2014-05-01           6.94
#
#       PM10 (ug/m3)  NO (ug/m3)  NO2 (ug/m3)  NOx (ppb)  NH3 (ug/m3)  ...  \
# 34           16.64        2.88         5.92       8.79         1.81  ...
# 2339          9.71        4.78        10.70      15.47         6.81  ...
# 4644          6.66        4.11         8.32      12.43         4.08  ...
# 6949         15.72        3.88         8.81      12.69         2.68  ...
# 9254         10.00        4.34        10.70      15.05         4.55  ...
#
#       Toluene (ug/m3)  Xylene (ug/m3)   AQI    AQI_Bucket  Wind_Speed (km/h)  \
# 34               1.17            1.23  72.0  Satisfactory              20.43
# 2339             4.16            1.74  17.0          Good              24.55
# 4644             1.89            1.17  25.0          Good              11.17
# 6949             3.63            1.14  19.0          Good              21.24
# 9254             2.80            2.64  15.0          Good              32.69
#
#       Humidity (%)  Deforestation_Rate_% Industry_Growth_%  CO2_Emission_MT  \
# 34           61.30                0.0062              1.52             6.99
# 2339         59.54                0.0043              0.14             5.72
# 4644         50.17                0.0084              1.29             5.39
# 6949         49.47                0.0110              1.42             4.97
# 9254         62.88                0.0042              1.37             6.12
#
#       Population_Density_per_SqKm
# 34                         171.90
# 2339                       102.32
# 4644                       182.75
# 6949                        35.13
# 9254                       176.44
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (331920, 24)

# %%
len(df["City"].unique())
# Out:
# 2270

# %%
df[["City"]].groupby("City").value_counts()
# Out:
# City
# 10th of Ramadan    144
# 6th of October     144
# Aba                144
# Abakaliki          144
# Abakan             144
#                   ...
# Zulfi              144
# Zunyi              144
# Zwickau            144
# eMalahleni         144
# Évreux             144
# Name: count, Length: 2270, dtype: int64

# %%
df[["City"]].groupby("City").value_counts().to_frame().groupby("count").value_counts()
# Out:
# count
# 144    2236
# 288      33
# 432       1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'State', 'City', 'Date', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)',
#        'NO (ug/m3)', 'NO2 (ug/m3)', 'NOx (ppb)', 'NH3 (ug/m3)', 'CO (mg/m3)',
#        'SO2 (ug/m3)', 'O3 (ug/m3)', 'Benzene (ug/m3)', 'Toluene (ug/m3)',
#        'Xylene (ug/m3)', 'AQI', 'AQI_Bucket', 'Wind_Speed (km/h)',
#        'Humidity (%)', 'Deforestation_Rate_%', 'Industry_Growth_%',
#        'CO2_Emission_MT', 'Population_Density_per_SqKm'],
#       dtype='object')

# %% [markdown]
# ## Colums by Category
# Index:
# - Country
# - State
# - City
# - Date
#
# Data:
# - PM2.5 (ug/m3)
# - PM10 (ug/m3)
# - NO (ug/m3)
# - NO2 (ug/m3)
# - NOx (ppb)
# - NH3 (ug/m3)
# - CO (mg/m3)
# - SO2 (ug/m3)
# - O3 (ug/m3)
# - Benzene (ug/m3)
# - Toluene (ug/m3)
# - Xylene (ug/m3)
# - AQI
# - Wind_Speed (km/h)
# - Humidity (%)
# - Deforestation_Rate_%
# - Industry_Growth_%
# - CO2_Emission_MT
#
# Context:
# - Population_Density_per_SqKm
#
# Supplement:
# - AQI_Bucket -> AQI categorized

# %%
df.dtypes
# Out:
# Country                         object
# State                           object
# City                            object
# Date                            object
# PM2.5 (ug/m3)                  float64
# PM10 (ug/m3)                   float64
# NO (ug/m3)                     float64
# NO2 (ug/m3)                    float64
# NOx (ppb)                      float64
# NH3 (ug/m3)                    float64
# CO (mg/m3)                     float64
# SO2 (ug/m3)                    float64
# O3 (ug/m3)                     float64
# Benzene (ug/m3)                float64
# Toluene (ug/m3)                float64
# Xylene (ug/m3)                 float64
# AQI                            float64
# AQI_Bucket                      object
# Wind_Speed (km/h)              float64
# Humidity (%)                   float64
# Deforestation_Rate_%           float64
# Industry_Growth_%              float64
# CO2_Emission_MT                float64
# Population_Density_per_SqKm    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Country                        0
# State                          0
# City                           0
# Date                           0
# PM2.5 (ug/m3)                  0
# PM10 (ug/m3)                   0
# NO (ug/m3)                     0
# NO2 (ug/m3)                    0
# NOx (ppb)                      0
# NH3 (ug/m3)                    0
# CO (mg/m3)                     0
# SO2 (ug/m3)                    0
# O3 (ug/m3)                     0
# Benzene (ug/m3)                0
# Toluene (ug/m3)                0
# Xylene (ug/m3)                 0
# AQI                            0
# AQI_Bucket                     0
# Wind_Speed (km/h)              0
# Humidity (%)                   0
# Deforestation_Rate_%           0
# Industry_Growth_%              0
# CO2_Emission_MT                0
# Population_Density_per_SqKm    0
# dtype: int64

# %%
city = pd.read_csv("../data/worldcities.csv")
city.head()
# Out:
#         city city_ascii      lat       lng    country iso2 iso3 admin_name  \
# 0      Tokyo      Tokyo  35.6850  139.7514      Japan   JP  JPN      Tōkyō
# 1    Jakarta    Jakarta  -6.1753  106.8269  Indonesia   ID  IDN    Jakarta
# 2      Delhi      Delhi  28.6600   77.2300      India   IN  IND      Delhi
# 3  Chongqing  Chongqing  29.5500  106.5069      China   CN  CHN  Chongqing
# 4  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN  Guangdong
#
#    capital  population          id
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  32054159.0  1156936556
# 4    admin  26940000.0  1156237133

# %%
supplement = pd.read_csv("../data/worldcities_supplement.csv")
supplement.head()
# Out:
#               city       city_ascii    country     lat           lon
# 0  Jakarta Selatan  Jakarta Selatan  Indonesia -6.2660  106.81350000
# 1    Jakarta Timur    Jakarta Timur  Indonesia -6.2521  106.88400000
# 2    Jakarta Pusat    Jakarta Pusat  Indonesia -6.1777  106.84030000
# 3    Jakarta Barat    Jakarta Barat  Indonesia -6.1676  106.76730000
# 4    Jakarta Utara    Jakarta Utara  Indonesia -6.1339  106.88230000

# %%
city.isnull().sum()
# Out:
# city              0
# city_ascii        2
# lat               0
# lng               0
# country           0
# iso2             36
# iso3              0
# admin_name      178
# capital       33906
# population     1214
# id                0
# dtype: int64

# %%
city = city.rename(columns={"lng": "lon"})
city = city[["city", "city_ascii", "country", "lat", "lon"]]
city = pd.concat([city, supplement], ignore_index=True)
city.head()
# Out:
#         city city_ascii    country      lat       lon
# 0      Tokyo      Tokyo      Japan  35.6850  139.7514
# 1    Jakarta    Jakarta  Indonesia  -6.1753  106.8269
# 2      Delhi      Delhi      India  28.6600     77.23
# 3  Chongqing  Chongqing      China  29.5500  106.5069
# 4  Guangzhou  Guangzhou      China  23.1300    113.26

# %%
city.dtypes
# Out:
# city           object
# city_ascii     object
# country        object
# lat           float64
# lon            object
# dtype: object

# %%
city["country"] = city["country"].replace("Korea, North", "North Korea")
city["country"] = city["country"].replace("Korea, South", "South Korea")

# %%
city["id"] = city["city_ascii"] + " | " + city["country"]
city.head()
# Out:
#         city city_ascii    country      lat       lon                   id
# 0      Tokyo      Tokyo      Japan  35.6850  139.7514        Tokyo | Japan
# 1    Jakarta    Jakarta  Indonesia  -6.1753  106.8269  Jakarta | Indonesia
# 2      Delhi      Delhi      India  28.6600     77.23        Delhi | India
# 3  Chongqing  Chongqing      China  29.5500  106.5069    Chongqing | China
# 4  Guangzhou  Guangzhou      China  23.1300    113.26    Guangzhou | China

# %%
df["City_id"] = df["City"] + " | " + df["Country"]
df.head()
# Out:
#         Country            State      City        Date  PM2.5 (ug/m3)  \
# 34    Australia  South Australia  Adelaide  2014-01-01          17.01
# 2339  Australia  South Australia  Adelaide  2014-02-01           7.16
# 4644  Australia  South Australia  Adelaide  2014-03-01           6.04
# 6949  Australia  South Australia  Adelaide  2014-04-01           6.48
# 9254  Australia  South Australia  Adelaide  2014-05-01           6.94
#
#       PM10 (ug/m3)  NO (ug/m3)  NO2 (ug/m3)  NOx (ppb)  NH3 (ug/m3)  ...  \
# 34           16.64        2.88         5.92       8.79         1.81  ...
# 2339          9.71        4.78        10.70      15.47         6.81  ...
# 4644          6.66        4.11         8.32      12.43         4.08  ...
# 6949         15.72        3.88         8.81      12.69         2.68  ...
# 9254         10.00        4.34        10.70      15.05         4.55  ...
#
#       Xylene (ug/m3)   AQI    AQI_Bucket  Wind_Speed (km/h)  Humidity (%)  \
# 34              1.23  72.0  Satisfactory              20.43         61.30
# 2339            1.74  17.0          Good              24.55         59.54
# 4644            1.17  25.0          Good              11.17         50.17
# 6949            1.14  19.0          Good              21.24         49.47
# 9254            2.64  15.0          Good              32.69         62.88
#
#       Deforestation_Rate_%  Industry_Growth_% CO2_Emission_MT  \
# 34                  0.0062               1.52            6.99
# 2339                0.0043               0.14            5.72
# 4644                0.0084               1.29            5.39
# 6949                0.0110               1.42            4.97
# 9254                0.0042               1.37            6.12
#
#       Population_Density_per_SqKm               City_id
# 34                         171.90  Adelaide | Australia
# 2339                       102.32  Adelaide | Australia
# 4644                       182.75  Adelaide | Australia
# 6949                        35.13  Adelaide | Australia
# 9254                       176.44  Adelaide | Australia
#
# [5 rows x 25 columns]

# %%
required_cities = set(df["City_id"].to_list())
available_cities = set(city["id"].to_list())

# %%
print("City")
print(f"Available: {len(required_cities.intersection(available_cities))}")
print(f"Unavailable: {len(required_cities - available_cities)}")
# Out:
# City
# Available: 1745
# Unavailable: 545

# %%
required_countries = set(df["Country"].to_list())
available_countries = set(city["country"].to_list())

# %%
print("Country")
print(f"Available: {len(required_countries.intersection(available_countries))}")
print(f"Unavailable: {len(required_countries - available_countries)}")
# Out:
# Country
# Available: 24
# Unavailable: 0

# %%
x = city[["country"]].groupby("country").value_counts()

# %%
x.to_frame().to_csv("x.csv")

# %%
missing_cities = required_cities - available_cities
u_city = df[["Country", "City_id"]].drop_duplicates(subset="City_id")
missing = u_city[u_city["City_id"].isin(missing_cities)][["Country"]].groupby("Country").value_counts()
missing
# Out:
# Country
# Australia          1
# Bangladesh        30
# Brazil            37
# China             39
# Egypt             78
# Ethiopia          42
# France            14
# Germany            7
# India             35
# Indonesia         11
# Japan             17
# Mexico            27
# Nigeria           16
# Pakistan          16
# Philippines       42
# Russia            11
# Saudi Arabia      48
# South Africa      11
# South Korea       41
# Thailand           6
# United Kingdom     9
# United States      1
# Vietnam            6
# Name: count, dtype: int64

# %%
len(required_cities.intersection(available_cities))
# Out:
# 1745

# %%
city = city.drop_duplicates(subset="id")

# %%
used_cities = city[city["id"].isin(required_cities)].reset_index()
used_cities
# Out:
#       index              city        city_ascii      country        lat  \
# 0         4         Guangzhou         Guangzhou        China  23.130000
# 1         5            Mumbai            Mumbai        India  19.075800
# 2         6            Manila            Manila  Philippines  14.595800
# 3         9             Seoul             Seoul  South Korea  37.560000
# 4        12           Kolkāta           Kolkata        India  22.567500
# ...     ...               ...               ...          ...        ...
# 1740  49993     Jakarta Timur     Jakarta Timur    Indonesia  -6.252100
# 1741  49994     Jakarta Pusat     Jakarta Pusat    Indonesia  -6.177700
# 1742  49995     Jakarta Barat     Jakarta Barat    Indonesia  -6.167600
# 1743  49996     Jakarta Utara     Jakarta Utara    Indonesia  -6.133900
# 1744  49997  Kepulauan Seribu  Kepulauan Seribu    Indonesia  -5.635047
#
#                     lon                            id
# 0                113.26             Guangzhou | China
# 1               72.8775                Mumbai | India
# 2              120.9772          Manila | Philippines
# 3                126.99           Seoul | South Korea
# 4                 88.37               Kolkata | India
# ...                 ...                           ...
# 1740       106.88400000     Jakarta Timur | Indonesia
# 1741       106.84030000     Jakarta Pusat | Indonesia
# 1742       106.76730000     Jakarta Barat | Indonesia
# 1743       106.88230000     Jakarta Utara | Indonesia
# 1744  106.580354066135.  Kepulauan Seribu | Indonesia
#
# [1745 rows x 7 columns]

# %%
import plotly.express as px

fig = px.scatter_geo(
    used_cities,
    lat="lat",
    lon="lon",
    hover_name="id"
)

fig.show()
